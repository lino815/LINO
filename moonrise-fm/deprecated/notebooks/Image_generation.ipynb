# %% [markdown]
# # Generate images

# %%
import sys
sys.path.insert(0, "..")
import matplotlib.pyplot as plt

from lib import make_image, make_image_dir, save_images, mask2rgb

# %% [markdown]
# ### Create training images

# %%
width,height = 200,400
n_images = 10
export_dir = '../data/images_test'

images = [make_image(width,height) for i in range(n_images)]
save_images(export_dir, images)
# Out:
# C:\Users\p.dyroey\Downloads\unet-multiclass-pytorch-master\notebooks\..\lib\generate_images.py:113: FutureWarning: `selem` is a deprecated argument name for `dilation`. It will be removed in version 1.0. Please use `footprint` instead.
#   img_line = dilation(img_line, selem=disk(thickness))

# %% [markdown]
# ### Image and mask sample

# %%
img = images[0][0]
mask = images[0][1]

fig, ax = plt.subplots(1, 2, figsize=(10, 8))
ax[0].imshow(img, cmap='gray')
ax[0].axis('off')
ax[1].imshow(mask2rgb(mask))
ax[1].axis('off')
# Out:
# (-0.5, 199.5, 399.5, -0.5)

# %%
mask.shape
# Out:
# (400, 200)

# %%
img.shape
# Out:
# (400, 200, 3)
